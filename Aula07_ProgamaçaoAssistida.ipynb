# %% [markdown]
# <a href="https://colab.research.google.com/github/lzin58/Engenharia_de_Prompt_Aplica-oes_IA/blob/main/Aula07_Progama%C3%A7aoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #aula: Progamaçao Assistida
# Nome: Luciano Igor Santos De Freitas

# %%
# Define a list of numbers
numeros = [1, 2, 3, 4, 5, 6, 7]

# Initialize a variable to store the sum
soma = 0

# Iterate through each number in the list
for num in numeros:
  # Add the current number to the sum
  soma += num

# Print the final sum
print(soma)
# Out:
# 28

# %% [markdown]
# #Numeros Primos

# %% [markdown]
# #Versao de string

# %%
def inverte_texto (testo):
  invertido = ""
  for letra in texto:
    invertido = letra + invertido
    return invertido
